# %%
# Topics to be covered -
# (1) Merge
# (2) Join
# (3) Groupby

# %%
# Importing importing libraries
import pandas as pd

# %%
# Creating the dataset
data1 = {'key' : ['K0', 'K1', 'K2', 'K4'],
        'Name' : ['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age' : [23,24,25,26]}

data2 = {'key' : ['K0', 'K1', 'K2', 'K3'],
        'Address' : ['Nagpur', 'Kanpur', 'Allahabad', 'Aurangabad'],
        'Qualification' : ['BTech', 'BCA', 'BE', 'BBA']}

df = pd.DataFrame(data1)
df1 = pd.DataFrame(data2)

print(df, '\n\n', df1)
# Out:
#   key    Name  Age
# 0  K0     Jai   23
# 1  K1  Princi   24
# 2  K2  Gaurav   25
# 3  K3    Anuj   26
#
#    key     Address Qualification
# 0  K0      Nagpur         BTech
# 1  K1      Kanpur           BCA
# 2  K2   Allahabad            BE
# 3  K3  Aurangabad           BBA

# %%
# Merge => SQL Joins

# %%
# Merge df and df1 using key column

# %%
# Merge with a single key
res = pd.merge(df, df1, on = 'key')
res
# Out:
#   key    Name  Age     Address Qualification
# 0  K0     Jai   23      Nagpur         BTech
# 1  K1  Princi   24      Kanpur           BCA
# 2  K2  Gaurav   25   Allahabad            BE
# 3  K3    Anuj   26  Aurangabad           BBA

# %%
# Creating the dataset
data1 = {'key' : ['K0', 'K1', 'K2', 'K4'],
        'Name' : ['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age' : [23,24,25,26]}

data2 = {'key' : ['K0', 'K1', 'K2', 'K3'],
        'Address' : ['Nagpur', 'Kanpur', 'Allahabad', 'Aurangabad'],
        'Qualification' : ['BTech', 'BCA', 'BE', 'BBA']}

df = pd.DataFrame(data1)
df1 = pd.DataFrame(data2)

print(df, '\n\n', df1)
# Out:
#   key    Name  Age
# 0  K0     Jai   23
# 1  K1  Princi   24
# 2  K2  Gaurav   25
# 3  K4    Anuj   26
#
#    key     Address Qualification
# 0  K0      Nagpur         BTech
# 1  K1      Kanpur           BCA
# 2  K2   Allahabad            BE
# 3  K3  Aurangabad           BBA

# %%
# Merge with a single key
res = pd.merge(df, df1, on = 'key')
res
# Out:
#   key    Name  Age    Address Qualification
# 0  K0     Jai   23     Nagpur         BTech
# 1  K1  Princi   24     Kanpur           BCA
# 2  K2  Gaurav   25  Allahabad            BE

# %%
# Creating the dataset
data1 = {'key' : ['K0', 'K1', 'K2', 'K3'],
         'key1' : ['K0', 'K1', 'K2', 'K3'],
        'Name' : ['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age' : [23,24,25,26]}

data2 = {'key' : ['K0', 'K1', 'K2', 'K3'],
         'key1' : ['K0', 'K1', 'K2', 'K3'],
        'Address' : ['Nagpur', 'Kanpur', 'Allahabad', 'Aurangabad'],
        'Qualification' : ['BTech', 'BCA', 'BE', 'BBA']}

df = pd.DataFrame(data1)
df1 = pd.DataFrame(data2)

print(df, '\n\n', df1)
# Out:
#   key key1    Name  Age
# 0  K0   K0     Jai   23
# 1  K1   K1  Princi   24
# 2  K2   K2  Gaurav   25
# 3  K3   K3    Anuj   26
#
#    key key1     Address Qualification
# 0  K0   K0      Nagpur         BTech
# 1  K1   K1      Kanpur           BCA
# 2  K2   K2   Allahabad            BE
# 3  K3   K3  Aurangabad           BBA

# %%
# Composite key
# What is a composite key?
# A key = unique combination of value across multiple columns

# composite_key = col1 + col2
# col1 | col2
# 1   | A
# 1  | B

# 1 + A
# 1 + B

# Merging with composite keys

# %%
# Creating the dataset
data1 = {'key' : ['K0', 'K1', 'K2', 'K3'],
         'key1' : ['K0', 'K1', 'K2', 'K3'],
        'Name' : ['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age' : [23,24,25,26]}

data2 = {'key' : ['K0', 'K1', 'K2', 'K3'],
         'key1' : ['K8', 'K9', 'K2', 'K3'],
        'Address' : ['Nagpur', 'Kanpur', 'Allahabad', 'Aurangabad'],
        'Qualification' : ['BTech', 'BCA', 'BE', 'BBA']}
df = pd.DataFrame(data1)
df1 = pd.DataFrame(data2)
# print(df, '\n\n', df1)

# Merge with multiple keys (composite key)
res = pd.merge(df, df1, how = 'outer', on = ['key', 'key1'])
res
# What will be the output? How many rows in the output?
# If I do left join, what is the output?
# If I do outer join, what is the output?
# Out:
#   key key1    Name   Age     Address Qualification
# 0  K0   K0     Jai  23.0         NaN           NaN
# 1  K1   K1  Princi  24.0         NaN           NaN
# 2  K2   K2  Gaurav  25.0   Allahabad            BE
# 3  K3   K3    Anuj  26.0  Aurangabad           BBA
# 4  K0   K8     NaN   NaN      Nagpur         BTech
# 5  K1   K9     NaN   NaN      Kanpur           BCA

# %%
# Merge with multiple keys (composite key)
res = pd.merge(df, df1, on = ['key', 'key1'])
# res

# What will be the output?

# %%
# Merge with multiple keys (composite key)
res = pd.merge(df, df1, on = ['key', 'key1'])
res
# Out:
#   key key1    Name  Age     Address Qualification
# 0  K0   K0     Jai   23      Nagpur         BTech
# 1  K1   K1  Princi   24      Kanpur           BCA
# 2  K2   K2  Gaurav   25   Allahabad            BE
# 3  K3   K3    Anuj   26  Aurangabad           BBA

# %%
# Creating the dataset
data1 = {'key' : ['K0', 'K1', 'K2', 'K3'],
         'key1' : ['K0', 'K1', 'K0', 'K1'],
        'Name' : ['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age' : [23,24,25,26]}

data2 = {'key' : ['K0', 'K1', 'K2', 'K3'],
         'key1' : ['K0', 'K0', 'K0', 'K0'],
        'Address' : ['Nagpur', 'Kanpur', 'Allahabad', 'Aurangabad'],
        'Qualification' : ['BTech', 'BCA', 'BE', 'BBA']}

df = pd.DataFrame(data1)
df1 = pd.DataFrame(data2)

print(df, '\n\n', df1)
# Out:
#   key key1    Name  Age
# 0  K0   K0     Jai   23
# 1  K1   K1  Princi   24
# 2  K2   K0  Gaurav   25
# 3  K3   K1    Anuj   26
#
#    key key1     Address Qualification
# 0  K0   K0      Nagpur         BTech
# 1  K1   K0      Kanpur           BCA
# 2  K2   K0   Allahabad            BE
# 3  K3   K0  Aurangabad           BBA

# %%
# Merge with multiple keys (composite key) using how argument
res = pd.merge(df, df1, how = 'left', on = ['key', 'key1'])
res
# Out:
#   key key1    Name  Age    Address Qualification
# 0  K0   K0     Jai   23     Nagpur         BTech
# 1  K1   K1  Princi   24        NaN           NaN
# 2  K2   K0  Gaurav   25  Allahabad            BE
# 3  K3   K1    Anuj   26        NaN           NaN

# %%
# Similarly, we can have how = 'right', how = 'outer', how = 'inner'.

# %%
# Merge with multiple keys (composite key) using how argument
res = pd.merge(df, df1, how = 'right', on = ['key', 'key1'])
res
# Out:
#   key key1    Name   Age     Address Qualification
# 0  K0   K0     Jai  23.0      Nagpur         BTech
# 1  K2   K0  Gaurav  25.0   Allahabad            BE
# 2  K1   K0     NaN   NaN      Kanpur           BCA
# 3  K3   K0     NaN   NaN  Aurangabad           BBA

# %%
# Merge with multiple keys (composite key) using how argument
res = pd.merge(df, df1, how = 'outer', on = ['key', 'key1'])
res
# Out:
#   key key1    Name   Age     Address Qualification
# 0  K0   K0     Jai  23.0      Nagpur         BTech
# 1  K1   K1  Princi  24.0         NaN           NaN
# 2  K2   K0  Gaurav  25.0   Allahabad            BE
# 3  K3   K1    Anuj  26.0         NaN           NaN
# 4  K1   K0     NaN   NaN      Kanpur           BCA
# 5  K3   K0     NaN   NaN  Aurangabad           BBA

# %%
# Merge with multiple keys (composite key) using how argument
res = pd.merge(df, df1, how = 'inner', on = ['key', 'key1'])
res
# Out:
#   key key1    Name  Age    Address Qualification
# 0  K0   K0     Jai   23     Nagpur         BTech
# 1  K2   K0  Gaurav   25  Allahabad            BE

# %%
# Creating the dataset
data1 = {'Name' : ['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age' : [23,24,25,26]}

data2 = {'Address' : ['Nagpur', 'Kanpur', 'Allahabad', 'Aurangabad'],
        'Qualification' : ['BTech', 'BCA', 'BE', 'BBA']}

df = pd.DataFrame(data1, index = ['K0', 'K1', 'K2', 'K3'])
df1 = pd.DataFrame(data2, index = ['K0', 'K2', 'K3', 'K4'])

print(df, '\n\n', df1)
# Out:
#       Name  Age
# K0     Jai   23
# K1  Princi   24
# K2  Gaurav   25
# K3    Anuj   26
#
#         Address Qualification
# K0      Nagpur         BTech
# K2      Kanpur           BCA
# K3   Allahabad            BE
# K4  Aurangabad           BBA

# %%
# Join()
res = df.join(df1)
res
# Out:
#       Name  Age    Address Qualification
# K0     Jai   23     Nagpur         BTech
# K1  Princi   24        NaN           NaN
# K2  Gaurav   25     Kanpur           BCA
# K3    Anuj   26  Allahabad            BE

# %%
# Join()
res1 = df.join(df1, how = 'outer')
res1
# Out:
#       Name   Age     Address Qualification
# K0     Jai  23.0      Nagpur         BTech
# K1  Princi  24.0         NaN           NaN
# K2  Gaurav  25.0      Kanpur           BCA
# K3    Anuj  26.0   Allahabad            BE
# K4     NaN   NaN  Aurangabad           BBA

# %%
# Creating the dataset
data1 = {'Name' : ['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age' : [23,24,25,26],
        'Key' : ['K0', 'K1', 'K2', 'K3']}

data2 = {'Address' : ['Nagpur', 'Kanpur', 'Allahabad', 'Aurangabad'],
        'Qualification' : ['BTech', 'BCA', 'BE', 'BBA']}

df = pd.DataFrame(data1)
df1 = pd.DataFrame(data2, index = ['K0', 'K2', 'K3', 'K4'])

print(df, '\n\n', df1)
# Out:
#      Name  Age Key
# 0     Jai   23  K0
# 1  Princi   24  K1
# 2  Gaurav   25  K2
# 3    Anuj   26  K3
#
#         Address Qualification
# K0      Nagpur         BTech
# K2      Kanpur           BCA
# K3   Allahabad            BE
# K4  Aurangabad           BBA

# %%
# Join()
res2 = df.join(df1, on = 'Key')
res2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [18], in <cell line: 2>()
#       1 # Join()
# ----> 2 res2 = df.join(df1, on = 'key')
#       3 res2
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/conda_data_science/lib/python3.9/site-packages/pandas/core/frame.py:9254, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort)
#    9100 def join(
#    9101     self,
#    9102     other: DataFrame | Series,
#    (...)
#    9107     sort: bool = False,
#    9108 ) -> DataFrame:
#    9109     """
#    9110     Join columns of another DataFrame.
#    9111
#    (...)
#    9252     5  K1  A5   B1
#    9253     """
# -> 9254     return self._join_compat(
#    9255         other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9256     )
#
# ...

# %%
# Define a dictionary containing employee data 
data1 = {'Name':['Jai', 'Princi', 'Gaurav'], 
        'Age':[27, 24, 22]} 
    
# Define a dictionary containing employee data 
data2 = {'Address':['Allahabad', 'Kannuaj', 'Allahabad', 'Kanpur'], 
        'Qualification':['MCA', 'Phd', 'Bcom', 'B.hons']} 
  
# Convert the dictionary into DataFrame  
df = pd.DataFrame(data1, index=pd.Index(['K0', 'K1', 'K2'], name = 'key'))
index = pd.MultiIndex.from_tuples([('K0', 'Y0'), ('K1', 'Y1'),
                                   ('K2', 'Y2'), ('K2', 'Y3')],
                                   names=['key', 'Y'])
# Convert the dictionary into DataFrame  
df1 = pd.DataFrame(data2, index = index)

print(df, "\n\n", df1)
# Out:
#        Name  Age
# key
# K0      Jai   27
# K1   Princi   24
# K2   Gaurav   22
#
#            Address Qualification
# key Y
# K0  Y0  Allahabad           MCA
# K1  Y1    Kannuaj           Phd
# K2  Y2  Allahabad          Bcom
#     Y3     Kanpur        B.hons

# %%
# Joining single index with multi indexes
result = df.join(df1, how = 'inner')
result
# Out:
#           Name  Age    Address Qualification
# key Y
# K0  Y0     Jai   27  Allahabad           MCA
# K1  Y1  Princi   24    Kannuaj           Phd
# K2  Y2  Gaurav   22  Allahabad          Bcom
#     Y3  Gaurav   22     Kanpur        B.hons

# %%
# Importing the dataset
df = pd.read_csv('nba.csv')
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
# How many rows does it have? - 458
# How many columns does it have? - 9
# What is the shape of the dataframe? - (458, 9) - gk.shape
# How many null values does it have?
# What is the datatype of Weight column?

# %%
df.shape
# Out:
# (458, 9)

# %%
# How many null values does it have?
df.isnull().sum().sum()    # concatentaion of method
# Out:
# 104

# %%
# Derive some conclusions on it
# What is this dataset about?
# Personal details of NBA players

# What are its attributes/columns? - What datapoints it holds?

# What are the type of questions you can ask?
    # How many teams are there?
    # How many players in each team?
    # What is the average age of players in each team?
    # Arrange the teams in decreasing order of average age
    # What is the average weight of players in each team?
    # Arrange the teams in decreasing order of average weight
    
    # How many players in Boston Celtics are from Texas college?
    # Which team has the highest player salary?
    # Which team has the highest average player salary?
    # Which position has the highest average salary?
    # Which position has the tallest players on average?
    # For Boston Celtics, which position has the 
    # youngest average age of players?

# %%
# Out:
# 30

# %%
# How many teams are there?
# Shubham - 30

df['Team'].nunique()
# Out:
# 30

# %%
# How many players in each team?

df.groupby('Team').count()
# Out:
#                         Name  Number  Position  Age  Height  Weight  College  \
# Team
# Atlanta Hawks             15      15        15   15      15      15       11
# Boston Celtics            15      15        15   15      15      15       13
# Brooklyn Nets             15      15        15   15      15      15       13
# Charlotte Hornets         15      15        15   15      15      15       13
# Chicago Bulls             15      15        15   15      15      15       12
# Cleveland Cavaliers       15      15        15   15      15      15       12
# Dallas Mavericks          15      15        15   15      15      15       12
# Denver Nuggets            15      15        15   15      15      15        9
# Detroit Pistons           15      15        15   15      15      15       15
# Golden State Warriors     15      15        15   15      15      15       12
# Houston Rockets           15      15        15   15      15      15       11
# ...

# %%
# Abhilasha
df['Team'].count()
# Out:
# 457

# %%
df['Team'].value_counts()
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Boston Celtics            15
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Dallas Mavericks          15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Utah Jazz                 15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: Team, dtype: int64

# %%
df.groupby('Team').count()['Name']
# Out:
# Team
# Atlanta Hawks             15
# Boston Celtics            15
# Brooklyn Nets             15
# Charlotte Hornets         15
# Chicago Bulls             15
# Cleveland Cavaliers       15
# Dallas Mavericks          15
# Denver Nuggets            15
# Detroit Pistons           15
# Golden State Warriors     15
# Houston Rockets           15
# Indiana Pacers            15
# Los Angeles Clippers      15
# Los Angeles Lakers        15
# Memphis Grizzlies         18
# Miami Heat                15
# Milwaukee Bucks           16
# Minnesota Timberwolves    14
# New Orleans Pelicans      19
# New York Knicks           16
# Oklahoma City Thunder     15
# Orlando Magic             14
# Philadelphia 76ers        15
# Phoenix Suns              15
# Portland Trail Blazers    15
# Sacramento Kings          15
# San Antonio Spurs         15
# Toronto Raptors           15
# Utah Jazz                 15
# Washington Wizards        15
# Name: Name, dtype: int64

# %%
Team
BS 1
AB 2
XY 3
DF 4
AB 5
XY 6

.count()

# %%
Team
BS
AB
XY
DF
AB
XY


BS | AB  | XY  | DF
1  | 1+1 | 1+1 | 1

BS | 1
AB | 2
XY | 2
DF | 1


.value_count()

# %%
df.groupby('Team').mean()['Age'].sort_values(ascending=False)
# Out:
# Team
# San Antonio Spurs         31.600000
# Dallas Mavericks          29.733333
# Cleveland Cavaliers       29.533333
# Los Angeles Clippers      29.466667
# Miami Heat                28.933333
# Memphis Grizzlies         28.388889
# Atlanta Hawks             28.200000
# Washington Wizards        27.866667
# Golden State Warriors     27.666667
# Los Angeles Lakers        27.533333
# Chicago Bulls             27.400000
# Oklahoma City Thunder     27.066667
# New York Knicks           27.000000
# New Orleans Pelicans      26.894737
# Houston Rockets           26.866667
# Sacramento Kings          26.800000
# Indiana Pacers            26.400000
# Minnesota Timberwolves    26.357143
# Detroit Pistons           26.200000
# Charlotte Hornets         26.133333
# Toronto Raptors           26.133333
# Phoenix Suns              25.866667
# Denver Nuggets            25.733333
# Brooklyn Nets             25.600000
# Orlando Magic             25.071429
# Portland Trail Blazers    25.066667
# ...

# %%
df.groupby('Team')&('Age').sort_value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 df.groupby('Team')&('Age').sort_value
#
# AttributeError: 'str' object has no attribute 'sort_value'

# %%
df.loc[:, ['Team', 'Age']].groupby('Team').mean().sort_values(
    by='Age', ascending=False)
# Out:
#                               Age
# Team
# San Antonio Spurs       31.600000
# Dallas Mavericks        29.733333
# Cleveland Cavaliers     29.533333
# Los Angeles Clippers    29.466667
# Miami Heat              28.933333
# Memphis Grizzlies       28.388889
# Atlanta Hawks           28.200000
# Washington Wizards      27.866667
# Golden State Warriors   27.666667
# Los Angeles Lakers      27.533333
# Chicago Bulls           27.400000
# Oklahoma City Thunder   27.066667
# New York Knicks         27.000000
# New Orleans Pelicans    26.894737
# Houston Rockets         26.866667
# Sacramento Kings        26.800000
# Indiana Pacers          26.400000
# Minnesota Timberwolves  26.357143
# Detroit Pistons         26.200000
# Charlotte Hornets       26.133333
# Toronto Raptors         26.133333
# Phoenix Suns            25.866667
# Denver Nuggets          25.733333
# Brooklyn Nets           25.600000
# Orlando Magic           25.071429
# Portland Trail Blazers  25.066667
# ...

# %%
# What is the average age of players in each team?
# Arrange the teams in decreasing order of average age


# Nishant
# df.groupby('Team').mean()['Age']
# df.groupby('Team').mean()['Age']

# %%
# df

# %%
# What is the average weight of players in each team?
# Arrange the teams in decreasing order of average weight



df.loc[:, ['Team', 'Weight']].groupby('Team').mean().sort_values(
    by='Weight', ascending=False)
# Out:
#                             Weight
# Team
# Oklahoma City Thunder   229.400000
# Minnesota Timberwolves  228.642857
# Cleveland Cavaliers     227.866667
# Los Angeles Lakers      227.066667
# Dallas Mavericks        227.000000
# Golden State Warriors   224.600000
# Milwaukee Bucks         224.062500
# San Antonio Spurs       223.933333
# New York Knicks         223.625000
# Indiana Pacers          222.266667
# Detroit Pistons         222.200000
# Philadelphia 76ers      222.133333
# Toronto Raptors         221.800000
# Sacramento Kings        221.333333
# Atlanta Hawks           221.266667
# New Orleans Pelicans    221.000000
# Charlotte Hornets       220.400000
# Houston Rockets         220.333333
# Utah Jazz               220.000000
# Los Angeles Clippers    219.733333
# Boston Celtics          219.466667
# Washington Wizards      219.000000
# Chicago Bulls           218.933333
# Phoenix Suns            218.600000
# Portland Trail Blazers  218.600000
# ...

# %%
# How many players in Boston Celtics are from Texas college?


# Which college has the most number of players across all teams?


# Which college has the most number of players in Boston Celtics?

# %%
# Subset df where players are from college Texas
df<fill this up>

# %%
df1 = df[df['Team'] == 'Boston Celtics' ] 
df1[df1['College'] == 'Texas']
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
#
#   College     Salary
# 0   Texas  7730337.0

# %%
df[(df['Team'] == 'Boston Celtics') & (df['College'] == 'Texas') ]
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
#
#   College     Salary
# 0   Texas  7730337.0

# %%
# df.loc;[('Players')('Boston Celtics')&('Players')('Texas')];

# %%
# Player college = 'Texas'
# Player team = 'Boston Celtics'

df[(df['Team'] == 'Boston Celtics') & (df['College'] == 'Texas')]    # Boolean Indexing
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
#
#   College     Salary
# 0   Texas  7730337.0

# %%
# Which team has the highest player salary?

df[df['Salary'] == df['Salary'].max()]['Team']
# Out:
# 109    Los Angeles Lakers
# Name: Team, dtype: object

# %%
# Which team has the highest average player salary?




# df[df['Salary'] == df['Salary'].max()]['Team']
# Out:
# Series([], Name: Team, dtype: object)

# %%
df.groupby('Team').mean()['Salary'].sort_values(ascending=False)[0]
# Out:
# 7642049.214285715

# %%
df[['Team', 'Salary']].groupby('Team').mean().sort_values(
    by='Salary',ascending=False).index[0]
# Out:
# 'Cleveland Cavaliers'

# %%
# Which position has the highest average player salary?

df[['Position', 'Salary']].groupby('Position').mean().sort_values(
    by='Salary',ascending=False).index[0]
# Out:
# 'C'

# %%
    # Which team has the highest average player salary?
    
    
    
    
    
    # Which position has the tallest players on average?
    # For Boston Celtics, which position has the 
    # youngest average age of players?

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
# Sum of null values
df.isnull().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
gk.head()
# Out:
#                Name            Team  Number Position   Age Height  Weight  \
# 0     Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1       Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2      John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3       R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4     Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..              ...             ...     ...      ...   ...    ...     ...
# 442   Trevor Booker       Utah Jazz    33.0       PF  28.0    6-8   228.0
# 443      Trey Burke       Utah Jazz     3.0       PG  23.0    6-1   191.0
# 444      Alec Burks       Utah Jazz    10.0       SG  24.0    6-6   214.0
# 445      Dante Exum       Utah Jazz    11.0       PG  20.0    6-6   190.0
# 446  Derrick Favors       Utah Jazz    15.0       PF  24.0   6-10   265.0
#
#                College      Salary
# 0                Texas   7730337.0
# ...

# %%
# applying groupby() function
gk = df.groupby('Team')
gk.first()
# Out:
#                                          Name  Number Position   Age Height  \
# Team
# Atlanta Hawks                   Kent Bazemore    24.0       SF  26.0    6-5
# Boston Celtics                  Avery Bradley     0.0       PG  25.0    6-2
# Brooklyn Nets                Bojan Bogdanovic    44.0       SG  27.0    6-8
# Charlotte Hornets               Nicolas Batum     5.0       SG  27.0    6-8
# Chicago Bulls                Cameron Bairstow    41.0       PF  25.0    6-9
# Cleveland Cavaliers       Matthew Dellavedova     8.0       PG  25.0    6-4
# Dallas Mavericks              Justin Anderson     1.0       SG  22.0    6-6
# Denver Nuggets                 Darrell Arthur     0.0       PF  28.0    6-9
# Detroit Pistons                  Joel Anthony    50.0        C  33.0    6-9
# Golden State Warriors         Leandro Barbosa    19.0       SG  33.0    6-3
# Houston Rockets                  Trevor Ariza     1.0       SF  30.0    6-8
# ...

# %%
# Finding the values in Team Boston Celtics
gk.get_group('Boston Celtics')
# Out:
#                Name  Number Position   Age Height  Weight            College  \
# 0     Avery Bradley     0.0       PG  25.0    6-2   180.0              Texas
# 1       Jae Crowder    99.0       SF  25.0    6-6   235.0          Marquette
# 2      John Holland    30.0       SG  27.0    6-5   205.0  Boston University
# 3       R.J. Hunter    28.0       SG  22.0    6-5   185.0      Georgia State
# 4     Jonas Jerebko     8.0       PF  29.0   6-10   231.0                NaN
# 5      Amir Johnson    90.0       PF  29.0    6-9   240.0                NaN
# 6     Jordan Mickey    55.0       PF  21.0    6-8   235.0                LSU
# 7      Kelly Olynyk    41.0        C  25.0    7-0   238.0            Gonzaga
# 8      Terry Rozier    12.0       PG  22.0    6-2   190.0         Louisville
# 9      Marcus Smart    36.0       PG  22.0    6-4   220.0     Oklahoma State
# 10  Jared Sullinger     7.0        C  24.0    6-9   260.0         Ohio State
# ...

# %%
# groupby() on multiple columns
gkk = df.groupby(['Team', 'Position'])
gkk.first()
# Out:
#                                          Name  Number   Age Height  Weight  \
# Team               Position
# Atlanta Hawks      C               Al Horford    15.0  30.0   6-10   245.0
#                    PF          Kris Humphries    43.0  31.0    6-9   235.0
#                    PG         Dennis Schroder    17.0  22.0    6-1   172.0
#                    SF           Kent Bazemore    24.0  26.0    6-5   201.0
#                    SG        Tim Hardaway Jr.    10.0  24.0    6-6   205.0
# ...                                       ...     ...   ...    ...     ...
# Washington Wizards C            Marcin Gortat    13.0  32.0   6-11   240.0
#                    PF             Drew Gooden    90.0  34.0   6-10   250.0
#                    PG          Ramon Sessions     7.0  30.0    6-3   190.0
#                    SF            Jared Dudley     1.0  30.0    6-7   225.0
#                    SG           Alan Anderson     6.0  33.0    6-6   220.0
#
# ...

# %%
# Count() function in groupby
df.groupby('Team').count()
# Out:
#                         Name  Number  Position  Age  Height  Weight  College  \
# Team
# Atlanta Hawks             15      15        15   15      15      15       11
# Boston Celtics            15      15        15   15      15      15       13
# Brooklyn Nets             15      15        15   15      15      15       13
# Charlotte Hornets         15      15        15   15      15      15       13
# Chicago Bulls             15      15        15   15      15      15       12
# Cleveland Cavaliers       15      15        15   15      15      15       12
# Dallas Mavericks          15      15        15   15      15      15       12
# Denver Nuggets            15      15        15   15      15      15        9
# Detroit Pistons           15      15        15   15      15      15       15
# Golden State Warriors     15      15        15   15      15      15       12
# Houston Rockets           15      15        15   15      15      15       11
# ...

# %%
# Sum() function in groupby
df.groupby('Team')['Salary'].sum()
# Out:
# Team
# Atlanta Hawks              72902950.0
# Boston Celtics             58541068.0
# Brooklyn Nets              52528475.0
# Charlotte Hornets          78340920.0
# Chicago Bulls              86783378.0
# Cleveland Cavaliers       106988689.0
# Dallas Mavericks           71198732.0
# Denver Nuggets             60121930.0
# Detroit Pistons            67168263.0
# Golden State Warriors      88868997.0
# Houston Rockets            75283021.0
# Indiana Pacers             66751826.0
# Los Angeles Clippers       94854640.0
# Los Angeles Lakers         71770431.0
# Memphis Grizzlies          76550880.0
# Miami Heat                 82515673.0
# Milwaukee Bucks            69603517.0
# Minnesota Timberwolves     59709697.0
# New Orleans Pelicans       82750774.0
# New York Knicks            73303898.0
# Oklahoma City Thunder      93765298.0
# Orlando Magic              60161470.0
# Philadelphia 76ers         30992894.0
# Phoenix Suns               63445135.0
# ...

# %%
# Mean() function in groupby
df.groupby('Team')['Salary'].mean()
# Out:
# Team
# Atlanta Hawks             4.860197e+06
# Boston Celtics            4.181505e+06
# Brooklyn Nets             3.501898e+06
# Charlotte Hornets         5.222728e+06
# Chicago Bulls             5.785559e+06
# Cleveland Cavaliers       7.642049e+06
# Dallas Mavericks          4.746582e+06
# Denver Nuggets            4.294424e+06
# Detroit Pistons           4.477884e+06
# Golden State Warriors     5.924600e+06
# Houston Rockets           5.018868e+06
# Indiana Pacers            4.450122e+06
# Los Angeles Clippers      6.323643e+06
# Los Angeles Lakers        4.784695e+06
# Memphis Grizzlies         5.467920e+06
# Miami Heat                6.347359e+06
# Milwaukee Bucks           4.350220e+06
# Minnesota Timberwolves    4.593054e+06
# New Orleans Pelicans      4.355304e+06
# New York Knicks           4.581494e+06
# Oklahoma City Thunder     6.251020e+06
# Orlando Magic             4.297248e+06
# Philadelphia 76ers        2.213778e+06
# Phoenix Suns              4.229676e+06
# ...

# %%
# Functions that can be used with groupby -
# (1) sum()
# (2) count()
# (3) mean()
# (4) median()
# (5) min()
# (6) max()
# (7) mode()
# (8) std()
# (9) var()

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# Filtering using logical operator

# Find how many players are above the age of 30 years
# df[df[col_name] > value]


# Find their average salary


# Find number of players above height of 6 feet 2 inches

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
# Find number of players above height of 6 feet 2 inches

# %%
# Out:
# 340

# %%
df[['Players','Height']].groupby('Players').mean().sort_values(by='Players',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [127], in <cell line: 1>()
# ----> 1 df[['Players','Height']].groupby('Players').mean().sort_values(by='Players',ascending=False)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/conda_data_science/lib/python3.9/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/conda_data_science/lib/python3.9/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
df['Height']
# Out:
# 0       6-2
# 1       6-6
# 2       6-5
# 3       6-5
# 4      6-10
#        ...
# 453     6-3
# 454     6-1
# 455     7-3
# 456     7-0
# 457     NaN
# Name: Height, Length: 458, dtype: object

# %%
print ("Input your height:") 
h_ft=(input('Feet:'))
h_inch=int(inch(Inch:))
h_inch+=h_ft*12
# Out:
#   Input In [131]
#     h_inch=int(inch(Inch:))
#                         ^
# SyntaxError: invalid syntax

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
# Print Height
df['Height'].unique()
# Out:
# array(['6-2', '6-6', '6-5', '6-10', '6-9', '6-8', '7-0', '6-4', '5-9',
#        '6-7', '6-3', '5-11', '6-11', '7-3', '6-0', '7-2', '6-1', '7-1',
#        nan], dtype=object)

# %%
# Find a way to convert this into feet and inch
df['Height'].unique()[0].split('-')
# Out:
# ['6', '2']

# %%
# Extract feet and convert to into
int(df['Height'].unique()[0].split('-')[0])
# Out:
# 6

# %%
# Convert into inches
int(df['Height'].unique()[0].split('-')[0]) * 12
# Out:
# 72

# %%
int(df['Height'].unique()[0].split('-')[1])
# Out:
# 2

# %%
(int(df['Height'].unique()[0].split('-')[0]) * 12 ) + 2
# Out:
# 74

# %%
# New column - Height_inches

# 6-2

# 6'2"
# 6feet 2inch

# %%
# Method 2:
# Height # Feet # Inch
'6-2'    |  6   | 2

# df['Feet'] > 6 & df['Inch'] > 2

# %%
# list the names starting with A
df[df['Name'].str.startswith('A', na=False)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [125], in <cell line: 2>()
#       1 # list the names starting with A
# ----> 2 df[df['Name'].str.startswith('A')]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/conda_data_science/lib/python3.9/site-packages/pandas/core/frame.py:3495, in DataFrame.__getitem__(self, key)
#    3492     return self.where(key)
#    3494 # Do we have a (boolean) 1d indexer?
# -> 3495 if com.is_bool_indexer(key):
#    3496     return self._getitem_bool_array(key)
#    3498 # We are left with two options: a single key, and a collection of keys,
#    3499 # We interpret tuples as collections only for non-MultiIndex
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/conda_data_science/lib/python3.9/site-packages/pandas/core/common.py:144, in is_bool_indexer(key)
# ...

# %%
df[df['Name'].str.startswith('A', na=False)]
# Out:
#                   Name                    Team  Number Position   Age Height  \
# 0        Avery Bradley          Boston Celtics     0.0       PG  25.0    6-2
# 5         Amir Johnson          Boston Celtics    90.0       PF  29.0    6-9
# 30       Arron Afflalo         New York Knicks     4.0       SG  30.0    6-5
# 78        Andrew Bogut   Golden State Warriors    12.0        C  31.0    7-0
# 83      Andre Iguodala   Golden State Warriors     9.0       SF  32.0    6-6
# 90    Anderson Varejao   Golden State Warriors    18.0       PF  33.0   6-11
# 104      Austin Rivers    Los Angeles Clippers    25.0       PG  23.0    6-4
# 108      Anthony Brown      Los Angeles Lakers     3.0       SF  23.0    6-7
# 125     Archie Goodwin            Phoenix Suns    20.0       SG  21.0    6-5
# 128           Alex Len            Phoenix Suns    21.0        C  22.0    7-1
# 135      Alan Williams            Phoenix Suns    15.0        C  23.0    6-8
# ...

# %%
type(df['Height'][0])
# Out:
# str

# %%
# Numerical value represented as a string
df['Height']

# 6 feet 2 inch -> 6-2
# Out:
# 0       6-2
# 1       6-6
# 2       6-5
# 3       6-5
# 4      6-10
#        ...
# 453     6-3
# 454     6-1
# 455     7-3
# 456     7-0
# 457     NaN
# Name: Height, Length: 458, dtype: object

# %%
# Step 1: Separate out the feet and inch pat from this string

# 6-2 => 6 and 2
df['Height'].str.split('-')
# Out:
# 0       [6, 2]
# 1       [6, 6]
# 2       [6, 5]
# 3       [6, 5]
# 4      [6, 10]
#         ...
# 453     [6, 3]
# 454     [6, 1]
# 455     [7, 3]
# 456     [7, 0]
# 457        NaN
# Name: Height, Length: 458, dtype: object

# %%
# Step 2: Create 2 columns
# Height_Feet | Height_Inch

df[] | df[]

# %%
df['Height_Feet'] = None

# %%
df['Height_Inch'] = None

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary', 'Height_Feet', 'Height_Inch'],
#       dtype='object')

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary Height_Feet Height_Inch
# 0              Texas  7730337.0        None        None
# 1          Marquette  6796117.0        None        None
# 2  Boston University        NaN        None        None
# 3      Georgia State  1148640.0        None        None
# 4                NaN  5000000.0        None        None

# %%
# Step 3: df['Height'] => split it => list
# '6-2' => ['6', '2'] 
# assign df['Height_Feet'] as 6
# assign df[Height_Inch]   as 2
df[['Height_Feet', 'Height_Inch']] = df['Height'].str.split('-', expand=True)

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary Height_Feet Height_Inch
# 0              Texas  7730337.0           6           2
# 1          Marquette  6796117.0           6           6
# 2  Boston University        NaN           6           5
# 3      Georgia State  1148640.0           6           5
# 4                NaN  5000000.0           6          10

# %%
type(df['Height_Feet'][0])
# Out:
# str

# %%
pd.to_numeric()

# %%
# Step 4: Convert the datatype of 
# 'Height_Feet' and 'Height_Inch' to int
# df['Height_Feet'].astype('int')

# Fill in the null/Nan values with -1
df['Height_Feet'] = df['Height_Feet'].fillna(-1).astype('int')
df['Height_Inch'] = df['Height_Inch'].fillna(-1).astype('int')

# %%
type(df['Height_Feet'][0])
# Out:
# numpy.int64

# %%
# Step 5: Writing a comparison between 6-2 inch => 74 inch
# Converting Height_Feet and Height_Inch into inches => Height_Feet * 12 + Height_Inch
df[<comparison inside>].count()

# %%
pd.to_numeric(df['Height_Feet'])
# Out:
# 0      6.0
# 1      6.0
# 2      6.0
# 3      6.0
# 4      6.0
#       ...
# 453    6.0
# 454    6.0
# 455    7.0
# 456    7.0
# 457    NaN
# Name: Height_Feet, Length: 458, dtype: float64
